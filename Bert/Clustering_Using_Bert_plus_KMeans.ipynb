# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamksingh1/Clustering/blob/main/Bert/Clustering_Using_Bert_plus_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.11.1+cu111)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.10.0+cu111)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.62.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.16.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (3.10.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.0.47)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (4.11.0)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.11.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2019.12.20)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.7.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (7.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)

# %%
from sentence_transformers import SentenceTransformer

# %%
## Import libraries
from nltk.cluster import KMeansClusterer
import nltk
import numpy as np

# %%
embedder = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/DeepAligned/Data/banking/dev.tsv",sep="\t")

# %%
df.shape
# Out:
# (1000, 2)

# %%
df.nunique()
# Out:
# text     1000
# label      77
# dtype: int64

# %%
df
# Out:
#                                                   text                          label
# 0    Could you please explain why I received a mess...        beneficiary_not_allowed
# 1             How did you guys get your exchange rate?                  exchange_rate
# 2                       I am still waiting on my card?                   card_arrival
# 3    Why is the purchase I made this morning still ...           pending_card_payment
# 4      I made a mistake and need to cancel a transfer.                cancel_transfer
# ..                                                 ...                            ...
# 995  Is it possible to transfer money to my credit ...             topping_up_by_card
# 996  I've just been married and need to update my name          edit_personal_details
# 997            How does someone else top up my account             topping_up_by_card
# 998     Why is the payment from my card still pending?           pending_card_payment
# 999      I wanted to take out $100 but I only got $20.  wrong_amount_of_cash_received
#
# [1000 rows x 2 columns]

# %%
# Utility function for generating sentence embedding from the text
def get_embeddinngs(text):
    return embedder.encode(text)

# %%
# %%time
# Generating sentence embedding from the text
df['emb'] = df['text'].apply(get_embeddinngs)
# Out:
# CPU times: user 50.3 s, sys: 116 ms, total: 50.4 s
# Wall time: 50.7 s

# %%
df
# Out:
#                                                   text  ...                                                emb
# 0    Could you please explain why I received a mess...  ...  [-0.4830286, -0.27165222, -0.42418325, 0.13459...
# 1             How did you guys get your exchange rate?  ...  [0.6504274, 0.6175015, -0.33170068, 0.331622, ...
# 2                       I am still waiting on my card?  ...  [-0.10394557, 0.5288769, -0.07015563, -0.51285...
# 3    Why is the purchase I made this morning still ...  ...  [0.22972134, -0.11898315, -0.36682656, -0.3464...
# 4      I made a mistake and need to cancel a transfer.  ...  [-0.14311454, -0.10506384, 0.07438872, -0.8786...
# ..                                                 ...  ...                                                ...
# 995  Is it possible to transfer money to my credit ...  ...  [0.14249371, 0.30876768, -0.12601331, -0.39804...
# 996  I've just been married and need to update my name  ...  [0.284741, 0.638832, 0.49244645, -1.2638571, 0...
# 997            How does someone else top up my account  ...  [0.089588344, -0.07996903, -0.5829425, -0.5621...
# 998     Why is the payment from my card still pending?  ...  [-0.22344202, 0.28667304, 0.058500335, -0.0574...
# 999      I wanted to take out $100 but I only got $20.  ...  [0.69798684, -0.15768874, 0.6523468, 0.4973138...
#
# [1000 rows x 3 columns]

# %%
def clustering_question(df,NUM_CLUSTERS = 77):

    sentences = df['text']

    X = np.array(df['emb'].tolist())

    kclusterer = KMeansClusterer(
        NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance,
        repeats=25,avoid_empty_clusters=True)

    assigned_clusters = kclusterer.cluster(X, assign_clusters=True)

    df['cluster'] = pd.Series(assigned_clusters, index=df.index)
    df['centroid'] = df['cluster'].apply(lambda x: kclusterer.means()[x])

    return df, assigned_clusters

# %%
# %%time
data,cluster_label = clustering_question(df)
# Out:
# CPU times: user 3min 37s, sys: 990 ms, total: 3min 38s
# Wall time: 3min 38s

# %%
data
# Out:
#                                                   text  ...                                           centroid
# 0    Could you please explain why I received a mess...  ...  [-0.07055746, -0.051681355, 0.3166883, -0.0734...
# 1             How did you guys get your exchange rate?  ...  [-0.00925918, 0.2807162, -0.12237299, 0.243977...
# 2                       I am still waiting on my card?  ...  [0.1423075, 0.109859206, 0.5488275, -0.6366570...
# 3    Why is the purchase I made this morning still ...  ...  [0.1423075, 0.109859206, 0.5488275, -0.6366570...
# 4      I made a mistake and need to cancel a transfer.  ...  [-0.18066737, 0.04175015, 0.17891014, -0.67805...
# ..                                                 ...  ...                                                ...
# 995  Is it possible to transfer money to my credit ...  ...  [-0.17252655, 0.35799894, 0.0001270771, 0.0303...
# 996  I've just been married and need to update my name  ...  [-0.20249534, -0.023389807, 0.20843203, -0.979...
# 997            How does someone else top up my account  ...  [0.13908267, 0.32292715, -0.3593569, -0.536101...
# 998     Why is the payment from my card still pending?  ...  [0.1423075, 0.109859206, 0.5488275, -0.6366570...
# 999      I wanted to take out $100 but I only got $20.  ...  [0.55591995, -0.12315625, 0.5052437, 0.6804508...
#
# [1000 rows x 5 columns]

# %%
from scipy.spatial import distance_matrix

# %%
def distance_from_centroid(row):
    return distance_matrix([row['emb']], [row['centroid']])[0][0]

# %%
# Compute centroid distance to the data
data['distance_from_centroid'] = data.apply(distance_from_centroid, axis=1)

# %%
data
# Out:
#                                                   text  ... distance_from_centroid
# 0    Could you please explain why I received a mess...  ...               9.077115
# 1             How did you guys get your exchange rate?  ...               8.861092
# 2                       I am still waiting on my card?  ...               9.513056
# 3    Why is the purchase I made this morning still ...  ...              11.644768
# 4      I made a mistake and need to cancel a transfer.  ...               6.793017
# ..                                                 ...  ...                    ...
# 995  Is it possible to transfer money to my credit ...  ...               8.060166
# 996  I've just been married and need to update my name  ...              11.521876
# 997            How does someone else top up my account  ...               8.807019
# 998     Why is the payment from my card still pending?  ...               7.582754
# 999      I wanted to take out $100 but I only got $20.  ...               3.408752
#
# [1000 rows x 6 columns]

# %%
data[data['distance_from_centroid']==0]
# Out:
#                                          text  ... distance_from_centroid
# 857  My disposable virtual card was rejected.  ...                    0.0
#
# [1 rows x 6 columns]

# %%
data['cluster'].nunique()
# Out:
# 77

# %%
data['cluster'].unique()
# Out:
# array([31,  0, 34, 22, 16, 67,  9, 20, 74,  6, 32, 49, 54, 35,  5, 72, 57,
#        48,  1, 56, 66, 73, 19, 28, 26, 41, 64, 45, 37,  2, 51, 39, 11,  8,
#        65, 23, 62, 40, 33, 50, 59, 60, 55, 47, 27, 44, 24, 63, 53, 52, 68,
#        15, 36, 21, 75, 43, 69, 18, 29, 46, 17, 71, 42,  3, 30, 13, 61, 70,
#        10, 76,  7, 14, 38, 12, 58, 25,  4])

# %%
data[data['cluster']==0]
# Out:
#                                                   text  ... distance_from_centroid
# 1             How did you guys get your exchange rate?  ...               8.861092
# 9       How do you decide what the exchange rates are?  ...               7.076403
# 33              Where do you get those exchange rates?  ...               6.706015
# 143  Which flat currencies are supported for holdin...  ...              10.703206
# 169  Do you hold money and if so, what currencies d...  ...               8.441095
# 218                How can I find your exchange rates?  ...               6.082565
# 233                    Which currencies do you handle?  ...               8.250682
# 403  I was wondering, Can I get my pay in another c...  ...               8.897820
# 408  What is the foreign exchange rate you will apply?  ...               8.726612
# 446           When exchanging, how much are the rates?  ...              10.062797
# 477      How can I dispute a direct debit transaction?  ...              10.007960
# 488         Can I receive payment in another currency?  ...               9.363765
# 530        Can I receive payments in another currency?  ...               9.338356
# 534  What kind of charges should I expect to exchan...  ...               7.154770
# 645                          What exchange rate is it?  ...               8.847683
# 664                   How does the exchange rate work?  ...               7.886781
# 771  Why is the exchange rate different than expect...  ...               9.600134
# 800  What are the charges if I exchange foreign cur...  ...               6.664513
# 811  Is there a few for exchanging foreign currencies?  ...              10.476925
# 863  Can you tell me what currencies I can use to a...  ...               9.385796
# 942  I'd like to know what you guys look at to deci...  ...              10.274851
#
# [21 rows x 6 columns]

# %%
res = data.sort_values('distance_from_centroid',ascending = True).groupby('cluster')

# %%
res.first()
# Out:
#                                                       text  ... distance_from_centroid
# cluster                                                     ...
# 0                      How can I find your exchange rates?  ...               6.082565
# 1            Where are the ATMs that I can use Mastercard?  ...               5.955158
# 2                               How can I exchange to EUR?  ...               7.307281
# 3              Which fiat currencies are supported by you?  ...               4.411849
# 4            I wanted to take out $100 but I only got $20.  ...               3.408752
# ...                                                    ...  ...                    ...
# 72                          How do I delete my account now  ...               6.438104
# 73       I am seeing in the App a some cash withdrawal ...  ...               6.222218
# 74       What is the process for activating my card and...  ...               6.751153
# 75                               Where is my virtual card?  ...               6.239634
# 76         Why has my money been returned back to my card.  ...               7.235498
#
# [77 rows x 5 columns]

# %%
for name,group in res:
    print(name)
    print(group[['text','label']])
    print(group[['distance_from_centroid']])
# Out:
# 0
#                                                   text                                    label
# 218                How can I find your exchange rates?                            exchange_rate
# 800  What are the charges if I exchange foreign cur...                          exchange_charge
# 33              Where do you get those exchange rates?                            exchange_rate
# 9       How do you decide what the exchange rates are?                            exchange_rate
# 534  What kind of charges should I expect to exchan...                          exchange_charge
# 664                   How does the exchange rate work?                            exchange_rate
# 233                    Which currencies do you handle?           supported_cards_and_currencies
# 169  Do you hold money and if so, what currencies d...                    fiat_currency_support
# 408  What is the foreign exchange rate you will apply?                            exchange_rate
# 645                          What exchange rate is it?                            exchange_rate
# 1             How did you guys get your exchange rate?                            exchange_rate
# 403  I was wondering, Can I get my pay in another c...                          receiving_money
# 530        Can I receive payments in another currency?                          receiving_money
# 488         Can I receive payment in another currency?                          receiving_money
# 863  Can you tell me what currencies I can use to a...           supported_cards_and_currencies
# 771  Why is the exchange rate different than expect...  wrong_exchange_rate_for_cash_withdrawal
# 477      How can I dispute a direct debit transaction?      direct_debit_payment_not_recognised
# 446           When exchanging, how much are the rates?                            exchange_rate
# 942  I'd like to know what you guys look at to deci...                            exchange_rate
# 811  Is there a few for exchanging foreign currencies?                          exchange_charge
# 143  Which flat currencies are supported for holdin...                    fiat_currency_support
#      distance_from_centroid
# 218                6.082565
# 800                6.664513
# 33                 6.706015
# 9                  7.076403
# 534                7.154770
# 664                7.886781
# 233                8.250682
# 169                8.441095
# 408                8.726612
# 645                8.847683
# 1                  8.861092
# 403                8.897820
# 530                9.338356
# 488                9.363765
# 863                9.385796
# 771                9.600134
# 477               10.007960
# 446               10.062797
# 942               10.274851
# 811               10.476925
# 143               10.703206
# 1
#                                               text        label
# 560  Where are the ATMs that I can use Mastercard?  atm_support
# 67   How can I find an ATM that accepts this card?  atm_support
# 24             The card can be used at which ATMs?  atm_support
# 482                   What ATM accepts Mastercard?  atm_support
# 685              Is there a Mastercard ATM nearby?  atm_support
# 172            Where is the closest ATM I can use?  atm_support
# 770       Is there a way to find an ATM around me?  atm_support
#      distance_from_centroid
# 560                5.955158
# 67                 6.603902
# 24                 6.980325
# 482                7.462855
# 685                7.806837
# 172                8.143820
# 770                8.162078
# 2
#                                                   text                  label
# 471                         How can I exchange to EUR?  fiat_currency_support
# 329                  Where can I get a card in the EU?        country_support
# 895              What's the transfer time from Europe?        transfer_timing
# 56                Will you be able to exchange to EUR?  fiat_currency_support
# 154      How long will this transfer from europe take?        transfer_timing
# 48      I live in the EU, can I get one of your cards?        country_support
# 108                       Can you do exchanges of EUR?  fiat_currency_support
# 793  How long does it take transfers from Europe to...        transfer_timing
# 427  If I were to use a European bank card for a to...  top_up_by_card_charge
# 328     Any chance of getting the card outside the UK?        country_support
#      distance_from_centroid
# 471                7.307281
# 329                7.434845
# 895                7.953218
# 56                 8.055730
# 154                8.611770
# 48                 8.771769
# 108                8.797216
# 793                9.912004
# 427               11.016338
# 328               12.212158
# 3
#                                                   text                  label
# 192        Which fiat currencies are supported by you?  fiat_currency_support
# 243               Which fiat currencies are supported?  fiat_currency_support
# 673       How can I hold and exchange fiat currencies?  fiat_currency_support
# 573  Which fiat currencies are supported for holdin...  fiat_currency_support
# 844  I need assistance with understanding which fia...  fiat_currency_support
# 581  Are there any fiat currencies that you will no...  fiat_currency_support
#      distance_from_centroid
# 192                4.411849
# 243                4.750423
# 673                5.267695
# 573                6.184659
# 844                7.727366
# 581                9.393594
# 4
#                                               text                          label
# 999  I wanted to take out $100 but I only got $20.  wrong_amount_of_cash_received
# 916              I requested $100 but only got $20  wrong_amount_of_cash_received
# 921  I was only given $20 when I tried to get $100  wrong_amount_of_cash_received
#      distance_from_centroid
# 999                3.408752
# 916                3.664799
# 921                4.341467
# 5
#                                                   text                    label
# 594            Can I exchange currencies with the app?         exchange_via_app
# 19           How can I exchange currencies in the app?         exchange_via_app
# 566  How do I go about exchanging currencies with t...         exchange_via_app
# 351  Can I use your app to exchange between USD and...         exchange_via_app
# 958        Can I use your app to exchange USD for GBP?         exchange_via_app
# 886  With this app, will I be able to exchange curr...         exchange_via_app
# 897                 Can I top up using my apple watch?  apple_pay_or_google_pay
# 657                Am I able to top up with Apple Pay?  apple_pay_or_google_pay
# 616             Is topping up with Apple Pay possible?  apple_pay_or_google_pay
# 49            Can I use this app for both USD and GBP?         exchange_via_app
# 284                 Is top-up possible with Apple Pay?  apple_pay_or_google_pay
# 890                Can I use my apple watch to top-up?  apple_pay_or_google_pay
# 797           Can I use my Apple Watch to pay for gas?  apple_pay_or_google_pay
# 319      Will be Apple Watch be able to let me top up?  apple_pay_or_google_pay
# 563  Can this app exchange American and English cur...         exchange_via_app
#      distance_from_centroid
# 594                8.291598
# 19                 8.493652
# 566                8.994904
# 351                9.111073
# 958                9.271614
# 886                9.335541
# 897                9.436705
# 657                9.790833
# 616                9.949257
# 49                10.036860
# 284               10.104488
# 890               10.182843
# 797               10.397943
# 319               10.681197
# 563               12.188235
# 6
#                                                   text                                    label
# 43   How much will I be charged for exchanging fore...                          exchange_charge
# 727  Will I be charged for exchanging foreign curre...                          exchange_charge
# 361  What fees are there for adding money using an ...                    top_up_by_card_charge
# 979  would I need to pay extra for exchanging curre...                          exchange_charge
# 11                          Fees for currency exchange                          exchange_charge
# 486  Are there any fees if I want to add money usin...                    top_up_by_card_charge
# 552           Where can i exchange between GBP and USD                         exchange_via_app
# 187                      How high is the exchange fee?                          exchange_charge
# 478  I'd like to know what the foreign exchange rat...                            exchange_rate
# 756         what is the exchange rate for foreign ATMs  wrong_exchange_rate_for_cash_withdrawal
# 263                  Why is your exchange rate so bad?         card_payment_wrong_exchange_rate
# 299          Is it possible to change from AUD to GBP?                         exchange_via_app
#      distance_from_centroid
# 43                 7.111777
# 727                7.534034
# 361                8.232930
# 979                8.316440
# 11                 8.542417
# 486                9.308260
# 552                9.506654
# 187                9.599820
# 478                9.869277
# 756               10.105027
# 263               11.548996
# 299               12.451757
# 7
#                                                   text                      label
# 516  I exchange currencies a lot.  Can I get a disc...            exchange_charge
# 460  Am I allowed to hold money in multiple currenc...      fiat_currency_support
# 747  Do I get a discount if I exchange currencies a...            exchange_charge
# 809  Can I have a discount if I exchange currency o...            exchange_charge
# 783  How do I go forth on holding money in multiple...      fiat_currency_support
# 356  There are multiple instances where you added a...   card_payment_fee_charged
# 955           A payment is showing twice. Why is that?  transaction_charged_twice
#      distance_from_centroid
# 516                6.914259
# 460                7.329026
# 747                7.561606
# 809                8.144728
# 783                8.305878
# 356                9.573347
# 955               10.543248
# 8
#                                                   text                        label
# 612  Is there a transaction limit for a disposable ...       disposable_card_limits
# 417                     How do I use disposable cards?  get_disposable_virtual_card
# 325             What is the limit on disposable cards?       disposable_card_limits
# 229  How many transactions can be made with a dispo...       disposable_card_limits
# 889                   Where do I get a disposable card  get_disposable_virtual_card
# 693  how many transactions can go on a disposable c...       disposable_card_limits
# 659              Is there a limit on disposable cards?       disposable_card_limits
# 548        How do I receive a disposable virtual card?  get_disposable_virtual_card
# 389  On my disposable card, is there a transaction ...       disposable_card_limits
# 398  What is the maximum number of transactions I c...       disposable_card_limits
# 760  Do you have the option for a disposable virtua...  get_disposable_virtual_card
# 487  I would like to know what the restrictions are...       disposable_card_limits
# 778  Tell me more about getting a virtual disposabl...  get_disposable_virtual_card
# 561  When will you be taking orders for disposable ...  get_disposable_virtual_card
# 150      Can you provide me a disposable virtual card?  get_disposable_virtual_card
# 940  What is the number of transactions for one dis...       disposable_card_limits
# 58   How can many disposable cards can I have per day?       disposable_card_limits
# 285  Are there any restrictions for the disposable ...       disposable_card_limits
# 795  Could you tell me about the restrictions that ...       disposable_card_limits
# 251   Please explain how disposable virtual card work.  get_disposable_virtual_card
#      distance_from_centroid
# 612                5.539949
# 417                5.684881
# 325                5.876834
# 229                5.905226
# 889                5.959659
# 693                6.088922
# 659                6.157795
# 548                6.289332
# 389                6.439942
# 398                6.605285
# 760                6.734454
# 487                7.007850
# 778                7.059649
# 561                7.195208
# 150                7.261629
# 940                7.419468
# 58                 7.448367
# 285                7.497883
# 795                7.825508
# 251                7.965766
# 9
#                                                   text                                             label
# 917  Where do I go to see the source of my availabl...                            verify_source_of_funds
# 114   How can I check to see where my funds come from?                            verify_source_of_funds
# 495                        How does one send me money?                                   receiving_money
# 50           What do I need to see my source of money?                            verify_source_of_funds
# 866            How do I know where my funds come from?                            verify_source_of_funds
# 321                 my money, where is it coming from?                            verify_source_of_funds
# 820  Show me how to look at the source of my curren...                            verify_source_of_funds
# 842                     Where is the cash I deposited?  balance_not_updated_after_cheque_or_cash_deposit
# 129  Please explain to me how to know where my fund...                            verify_source_of_funds
# 623                 Where did the money I deposit go??  balance_not_updated_after_cheque_or_cash_deposit
# 26                  want to know where funds come from                            verify_source_of_funds
# 463          what is the exchange rate when i get cash           wrong_exchange_rate_for_cash_withdrawal
# 565                           Can I top up using cash?                          top_up_by_cash_or_cheque
# 7    How long does it take for a cash withdrawal to...                           pending_cash_withdrawal
# 508               I must verify the source of my funds                            verify_source_of_funds
# 88    Do you support direct deposits from my employer?                                   receiving_money
# 969           How long do bank transfers usually take?           balance_not_updated_after_bank_transfer
# 690            what are weekend rates for getting cash           wrong_exchange_rate_for_cash_withdrawal
# 601                 Where is my last money transaction                transfer_not_received_by_recipient
# 531  Its been 3 days, How long will my transfer tak...                                   transfer_timing
#      distance_from_centroid
# 917                6.436352
# 114                6.578707
# 495                6.942855
# 50                 7.310477
# 866                7.338736
# 321                7.477209
# 820                7.581377
# 842                7.689670
# 129                7.857737
# 623                8.354398
# 26                 8.545874
# 463                8.655438
# 565                9.463401
# 7                 10.060741
# 508               10.623156
# 88                11.625898
# 969               11.824927
# 690               12.351033
# 601               12.536912
# 531               12.738347
# 10
#                                                   text                                    label
# 959  Why is the exchange rate so high? This should ...  wrong_exchange_rate_for_cash_withdrawal
# 678  I've been waiting for a top up to come through...                           pending_top_up
# 256                           I have been overcharged.                transaction_charged_twice
#      distance_from_centroid
# 959                8.625295
# 678                8.890340
# 256                9.547202
# 11
#                                                   text                                    label
# 484                   How long will the transfer take?                         pending_transfer
# 439            How long will my transfer stay pending?                         pending_transfer
# 55   How long do I have  to wait for my transaction...       transfer_not_received_by_recipient
# 954         How long will a transfer from the US take?                          transfer_timing
# 76   The transfer finally worked, but how long does...                         pending_transfer
# 406                           How long is US delivery?                   card_delivery_estimate
# 421    What is the length of a transaction completion?       transfer_not_received_by_recipient
# 947      Why does my transfer still say it is pending?                         pending_transfer
# 180            I am still waiting for a transfer I did  balance_not_updated_after_bank_transfer
# 359                    how long are my top ups pending                           pending_top_up
# 291  How long does it take for a new purchase to st...                     pending_card_payment
# 420       How long does it take for deliver to the US?                   card_delivery_estimate
# 810                      How long does transfers take?  balance_not_updated_after_bank_transfer
# 416                How do I get a new expiration date?                     card_about_to_expire
# 674  I have been waiting for my top-up to complete ...                           pending_top_up
# 903  I made a top up yesterday but it's still pending.                           pending_top_up
# 492                           How old do I need to be?                                age_limit
# 493                       What is the age requirement?                                age_limit
# 140           can I choose delivery times to suite me?                   card_delivery_estimate
#      distance_from_centroid
# 484                8.439070
# 439                8.638877
# 55                 8.674345
# 954                9.006600
# 76                 9.346682
# 406                9.480478
# 421               10.017409
# 947               10.173206
# 180               10.202958
# 359               10.419207
# 291               10.491067
# 420               10.508946
# 810               10.822495
# 416               11.465785
# 674               11.783613
# 903               12.294882
# 492               12.518582
# 493               12.740079
# 140               13.094236
# 12
#                                        text                  label
# 742                It declined my transfer.      declined_transfer
# 514    It appears my transfer was declined.      declined_transfer
# 962     I noticed my transfer was declined.      declined_transfer
# 711          You have declined my  payment.  declined_card_payment
# 772        Why was my transaction declined?        failed_transfer
# 665  Why are my transfers getting declined?      declined_transfer
#      distance_from_centroid
# 742                5.603253
# 514                5.686066
# 962                5.740085
# 711                7.313379
# 772                7.598301
# 665               10.102653
# 13
#                                                   text                                             label
# 456  The exchange rate is incorrect for my cash wit...           wrong_exchange_rate_for_cash_withdrawal
# 504  Why is the exchange rate wrong for my cash wit...           wrong_exchange_rate_for_cash_withdrawal
# 883  I withdrew some cash and the exchange rate see...           wrong_exchange_rate_for_cash_withdrawal
# 338  The wrong exchange rate was applied to me whil...           wrong_exchange_rate_for_cash_withdrawal
# 992  You've incorrectly calculated the exchange rat...           wrong_exchange_rate_for_cash_withdrawal
# 790  There is a cash withdrawal on my statement tha...                    cash_withdrawal_not_recognised
# 692  When I received my cash; they had my exchange ...           wrong_exchange_rate_for_cash_withdrawal
# 199  What does it mean if my cash withdrawal does n...                           pending_cash_withdrawal
# 773   I have a cash withdrawal that I don't recognize.                    cash_withdrawal_not_recognised
# 269  The exchange rate from my card payment isn't r...                  card_payment_wrong_exchange_rate
# 968  While abroad, I got cash, and the exchange rat...           wrong_exchange_rate_for_cash_withdrawal
# 759  Can you tell me why a cheque deposit isn't sho...  balance_not_updated_after_cheque_or_cash_deposit
# 404  I was charged an incorrect exchange rate for a...           wrong_exchange_rate_for_cash_withdrawal
# 595  There was an unexpected fee for my cash withdr...                            cash_withdrawal_charge
# 780  Why is the cash withdraw I made shown as pending?                           pending_cash_withdrawal
# 607         Exchange rate for my card payment is wrong                  card_payment_wrong_exchange_rate
# 378              There's an unauthorized cash withdraw                    cash_withdrawal_not_recognised
# 837             My cash withdrawal was declined.  Why?                          declined_cash_withdrawal
# 721  I think there was an error in your exchange rate.                  card_payment_wrong_exchange_rate
# 825  I tried withdrawing money in another country a...           wrong_exchange_rate_for_cash_withdrawal
# 695  Hi there, I came across a problem with my top ...                                   top_up_reverted
# 984                    I withdrew cash and was charged                            cash_withdrawal_charge
# 412  I am trying to transfer money and something is...                                   failed_transfer
# 815  There's a $200 withdrawal on my statement that...                    cash_withdrawal_not_recognised
#      distance_from_centroid
# 456                6.549084
# 504                6.660527
# 883                6.697423
# 338                6.729736
# 992                6.751055
# 790                7.207947
# 692                7.232208
# 199                7.277073
# 773                7.762259
# 269                8.279182
# 968                8.363464
# 759                8.631226
# 404                8.645216
# 595                8.738110
# 780                9.026283
# 607                9.031477
# 378                9.357474
# 837                9.561852
# 721                9.643696
# 825                9.819894
# 695                9.901429
# 984               10.534155
# 412               10.826913
# 815               11.207686
# 14
#                                                   text                           label
# 381  Can you accept my other card from the U.S.?  I...  supported_cards_and_currencies
# 758  I only have one more US credit card, is it acc...  supported_cards_and_currencies
#      distance_from_centroid
# 381                6.720889
# 758                6.720890
# 15
#                                                   text                                             label
# 234                     I don't recognize this payment                       card_payment_not_recognised
# 901                I have no way to prove my identity.                         unable_to_verify_identity
# 751           I don't have a way to prove my identity.                         unable_to_verify_identity
# 171  Why am I still not able to see the money I dep...  balance_not_updated_after_cheque_or_cash_deposit
# 216  Please help me!  My physical card isn't workin...                                  card_not_working
# 307      I don't recognize this payment at all!  Help!                       card_payment_not_recognised
# 101  I am having trouble transferring money to a be...                           beneficiary_not_allowed
# 985           I could not get the top-up to go through                                     top_up_failed
#      distance_from_centroid
# 234                9.210032
# 901                9.501397
# 751                9.677596
# 171                9.716739
# 216                9.920342
# 307               10.126012
# 101               10.631283
# 985               11.219944
# 16
#                                                   text                          label
# 535  My card got trapped inside an ATM, what should...                 card_swallowed
# 570  This is not right, I was told I could take out...         cash_withdrawal_charge
# 5    How can I request cash back? The ATM just gave...  wrong_amount_of_cash_received
# 526                The atm didn'y give me all the cash  wrong_amount_of_cash_received
# 113       Is the ATM broken? I can't get cash from it.       declined_cash_withdrawal
# 832      The ATM didn't give me the amount I asked for  wrong_amount_of_cash_received
# 200                                lost my card in atm                 card_swallowed
# 574  I just pulled money out of the ATM and was cha...         cash_withdrawal_charge
# 44              I have lost my credit card in the ATM!                 card_swallowed
# 746  I need help from someone in your department wi...                    atm_support
#      distance_from_centroid
# 535                6.871741
# 570                7.085244
# 5                  7.120257
# 526                7.192414
# 113                7.329834
# 832                7.370269
# 200                7.624118
# 574                8.207942
# 44                 8.310143
# 746               11.481060
# 17
#                                                   text                      label
# 451          Why is it required to verify my identity?        why_verify_identity
# 376            Why does my identity need verification?        why_verify_identity
# 776                         Must I verify my identity?        why_verify_identity
# 547        Why do I need to have my identity verified?        why_verify_identity
# 669               Am I supposed to verify my identity?        why_verify_identity
# 876          What is needed for identity verification?         verify_my_identity
# 238  For the identity check, do I need any kind of ...         verify_my_identity
# 752  Can you tell me what I need for identity valid...         verify_my_identity
# 512  What is the purpose of requiring my identifica...        why_verify_identity
# 871  What documents are required for proof of ident...         verify_my_identity
# 275             Why is my identity not being verified?  unable_to_verify_identity
# 781                  Help me verify my identification.  unable_to_verify_identity
# 215            What proof of identification is needed?         verify_my_identity
# 588            I don't know how to verify my identity.         verify_my_identity
# 305       What do I need in regards to identification?         verify_my_identity
# 426  If I don't have all my documents can they stil...         verify_my_identity
# 178  I keep being asked to verify my identity. Is t...        why_verify_identity
# 221  Why on earth do you need so much personal id i...        why_verify_identity
# 672           why does it take so long to verify my id  unable_to_verify_identity
#      distance_from_centroid
# 451                5.144348
# 376                5.448608
# 776                5.542952
# 547                5.718170
# 669                6.178409
# 876                7.033811
# 238                7.483919
# 752                7.897667
# 512                8.510780
# 871                8.703189
# 275                8.751023
# 781                8.965037
# 215                9.275861
# 588                9.314495
# 305                9.596063
# 426               10.014756
# 178               10.730199
# 221               11.512899
# 672               11.666150
# 18
#                                                   text                                             label
# 374  When is my balance going to update, I just tra...           balance_not_updated_after_bank_transfer
# 542  Why hasn't my account updated to reflect my cu...           balance_not_updated_after_bank_transfer
# 791  When will I see an updated balance after a tra...           balance_not_updated_after_bank_transfer
# 157  How long does a check take to show up in the a...  balance_not_updated_after_cheque_or_cash_deposit
# 277  When the time is right will this automatically...                                  automatic_top_up
# 259                       Will my GPB update my salary                                   receiving_money
# 653             DO I have to be 18 to open an account?                                         age_limit
#      distance_from_centroid
# 374                7.482881
# 542                7.542096
# 791                8.403396
# 157                9.123648
# 277               10.270960
# 259               10.630014
# 653               13.161144
# 19
#                                                   text                      label
# 333         In my statement, there was an extra €1 fee  extra_charge_on_statement
# 29              Why was I charged $1 in a transaction?  extra_charge_on_statement
# 317    Where did the  €1 fee in my statement come from  extra_charge_on_statement
# 311  Can you tell me about why the account I have w...  extra_charge_on_statement
# 609  There is an unexplained $1 charge on my statem...  extra_charge_on_statement
# 915  My statement is showing an extra £1 charge and...  extra_charge_on_statement
# 596   Why has another fee been placed on my statement?  extra_charge_on_statement
# 119        what is this extra charge with my purchase?   card_payment_fee_charged
# 340                I see a $1 charge in a transaction.  extra_charge_on_statement
# 766        why is there a service fee on my statement?  extra_charge_on_statement
# 875                         What does the €1 fee mean?  extra_charge_on_statement
# 367  Is the 1 pound charge I can see an error or an...  extra_charge_on_statement
# 874  I've been charged an extra £1 and I don't know...  extra_charge_on_statement
#      distance_from_centroid
# 333                7.152052
# 29                 7.574461
# 317                7.859951
# 311                8.150484
# 609                8.405661
# 915                8.651309
# 596                8.658763
# 119                8.891225
# 340                9.409226
# 766                9.471666
# 875                9.890507
# 367                9.936165
# 874               10.051237
# 20
#                                                   text                                    label
# 627  Can you tell me why I wasn't able to complete ...                          failed_transfer
# 85   How can I find out why my transfer didn't go t...                          failed_transfer
# 975          Why was I unable to complete my transfer?                          failed_transfer
# 816                     Why is my transfer not showing  balance_not_updated_after_bank_transfer
# 52             Why does my transfer say it is pending?                         pending_transfer
# 720                     Why can I not make a transfer?                          failed_transfer
# 787               Why is my transfer stuck on pending?                         pending_transfer
# 870  I am trying  to  transfer and  it has been  st...                  beneficiary_not_allowed
# 733  Why is a transfer I did recently still process...                         pending_transfer
# 987              Is there a reason my transfer failed?                          failed_transfer
# 981                  Why can't I complete my transfer?                          failed_transfer
# 829                       My transfer has not arrived.       transfer_not_received_by_recipient
# 59   Is there a specific source that the exchange r...                            exchange_rate
# 324                 A transfer could not be completed.                          failed_transfer
# 8               I attempted a transfer, but it failed.                          failed_transfer
# 437                          Can I stop a transaction?                          cancel_transfer
# 334           Can you  tell me how to get AUD not GBP?                         exchange_via_app
# 402                         Whats the transfer process                    transfer_into_account
#      distance_from_centroid
# 627                6.754098
# 85                 6.825073
# 975                6.911378
# 816                7.763160
# 52                 8.312250
# 720                8.535025
# 787                8.574381
# 870                9.199753
# 733                9.290091
# 987                9.343486
# 981                9.415792
# 829                9.943945
# 59                10.534965
# 324               11.008559
# 8                 11.147027
# 437               12.021122
# 334               12.537963
# 402               13.468769
# 21
#                                                   text                                    label
# 680           Can I have my money refunded for an item                           request_refund
# 740  I was charged a fee when I transferred my fund...                     transfer_fee_charged
# 568              Is there a fee for transferring money                     transfer_fee_charged
# 498          Do I get charged if I am receiving money?           top_up_by_bank_transfer_charge
# 662  I transferred money, but I think I've been cha...                     transfer_fee_charged
# 213             Why isn't the transferred money there?  balance_not_updated_after_bank_transfer
# 656  Why have I been charged a fee for cash withdra...                   cash_withdrawal_charge
# 227  I received a fee for obtaining cash, is this c...                   cash_withdrawal_charge
# 838  I just transferred some money. Why was I charg...                     transfer_fee_charged
# 812             Is there a charge for receiving money?           top_up_by_bank_transfer_charge
# 145         How can I transfer money to a beneficiary?                  beneficiary_not_allowed
# 250               Where is the refund on my statement?                    Refund_not_showing_up
# 826  Please tell me how to get a refund for somethi...                           request_refund
# 822        Why would a merchant revert a card payment?                   reverted_card_payment?
# 273  What is the time period for money to be transf...                          transfer_timing
# 932      How do I get a refund for something I bought?                           request_refund
# 483           Will I be charged for a cash withdrawal?                   cash_withdrawal_charge
# 468                How do I go about getting a refund?                           request_refund
# 176  What are the fees imposed when I make a transa...                 card_payment_fee_charged
# 364                     Money transfer help? How long?                          transfer_timing
# 253  why cant you just refund me instead of a merchant                    Refund_not_showing_up
# 358  What is the fee for accepting money from a for...                          exchange_charge
# 900  How can I find a way to transfer money without...                        declined_transfer
# 639  I transferred money from the US, How long does...                          transfer_timing
# 470        Why can't I transfer money to a beneficiary                  beneficiary_not_allowed
# 320                    I was charged for getting cash.                   cash_withdrawal_charge
# 862               I would like to get an item refunded                           request_refund
# 106                                   Give me a refund                           request_refund
# 858      How much will it cost me for a SEPA transfer?           top_up_by_bank_transfer_charge
# 510   do you have a fee for receiving a SEPA transfer?           top_up_by_bank_transfer_charge
#      distance_from_centroid
# 680                7.407035
# 740                7.533080
# 568                7.855828
# 498                7.962010
# 662                8.136682
# 213                8.263475
# 656                8.285323
# 227                8.456842
# 838                8.461981
# 812                8.488272
# 145                8.896228
# 250                9.011526
# 826                9.153726
# 822                9.160319
# 273                9.162228
# 932                9.169557
# 483                9.393533
# 468                9.454291
# 176                9.650435
# 364                9.658876
# 253                9.705234
# 358                9.799829
# 900               10.029964
# 639               10.147249
# 470               10.462044
# 320               10.527932
# 862               10.789859
# 106               11.751521
# 858               13.070476
# 510               13.639121
# 22
#                                                   text            label
# 4      I made a mistake and need to cancel a transfer.  cancel_transfer
# 128                        I wish to cancel a transfer  cancel_transfer
# 45   I recently made a transfer that I would like t...  cancel_transfer
# 379  I don't need to transfer anymore and I want to...  cancel_transfer
# 644                    I'm going to cancel a purchase.   request_refund
# 935                    I need to reverse a transaction  cancel_transfer
# 597  Hi, I made a transfer yesterday that I need to...  cancel_transfer
#      distance_from_centroid
# 4                  6.793017
# 128                7.712178
# 45                 8.022303
# 379                8.536302
# 644                8.928582
# 935                9.553152
# 597                9.886202
# 23
#                                                   text                                    label
# 845  If I bought something I didn't like, can I get...                           request_refund
# 501  I was charged the wrong exchange rate on a pur...         card_payment_wrong_exchange_rate
# 736  A foreign purchase I made has the incorrect ra...         card_payment_wrong_exchange_rate
# 166  Why was the wrong rate applied when I bought s...         card_payment_wrong_exchange_rate
# 323  I think I was charged extra on my payment on l...         card_payment_wrong_exchange_rate
# 562            I need a refund for something I bought.                           request_refund
# 62              I want a refund on the things i bought                           request_refund
# 904  The applied exchange rate is wrong for the cas...  wrong_exchange_rate_for_cash_withdrawal
# 474  I would like to receive a refund for something...                           request_refund
# 978  When I bought something abroad, the exchange r...         card_payment_wrong_exchange_rate
# 409     I would like my refund for this item I bought.                           request_refund
# 743  Your exchange rate was off.  I was charged ext...         card_payment_wrong_exchange_rate
# 884  The exchange rate looks wrong on a holiday pur...         card_payment_wrong_exchange_rate
# 537  I need to get some Euros for my holiday. Am I ...                         exchange_via_app
# 306  the exchange rate is wrong from something I go...         card_payment_wrong_exchange_rate
# 304  The exchange rate for my payment last Saturday...         card_payment_wrong_exchange_rate
#      distance_from_centroid
# 845                8.291362
# 501                8.650749
# 736                8.817327
# 166                8.909757
# 323                8.923753
# 562                9.034882
# 62                 9.052257
# 904                9.079702
# 474                9.375621
# 978                9.568745
# 409                9.960191
# 743               10.071793
# 884               10.077848
# 537               10.219420
# 306               10.483957
# 304               10.667594
# 24
#                                                   text                           label
# 168  How much is the charge to top up via credit card?           top_up_by_card_charge
# 995  Is it possible to transfer money to my credit ...              topping_up_by_card
# 908  I would like to top up via credit card, which ...  supported_cards_and_currencies
# 497              how do i find top up for cash deposit        top_up_by_cash_or_cheque
# 87   How much is it to use my US debit or credit ca...           top_up_by_card_charge
# 939                      Can I top up using my cheque?        top_up_by_cash_or_cheque
# 813  I want to top up by using a credit card, which...  supported_cards_and_currencies
# 107  Do i have to top-up with my credit card before...              topping_up_by_card
# 91              Can I top up my balance with a cheque?        top_up_by_cash_or_cheque
# 840                    Will you accept my credit card?  supported_cards_and_currencies
# 126                   How do you top up with a cheque?        top_up_by_cash_or_cheque
# 828            Can I add to my account using a cheque?        top_up_by_cash_or_cheque
# 734        Where's the button to top up with a cheque?        top_up_by_cash_or_cheque
# 260                             Can I top up with cash        top_up_by_cash_or_cheque
# 709         I would like to use cash to make a top-up?        top_up_by_cash_or_cheque
# 585                     I would like to pay by cheque.        top_up_by_cash_or_cheque
#      distance_from_centroid
# 168                7.660012
# 995                8.060166
# 908                8.391973
# 497                8.413720
# 87                 8.430529
# 939                8.646398
# 813                8.851205
# 107                8.948500
# 91                 9.029906
# 840                9.086373
# 126                9.088752
# 828                9.097941
# 734                9.484740
# 260               10.550379
# 709               10.597013
# 585               11.119085
# 25
#                                          text                     label
# 857  My disposable virtual card was rejected.  virtual_card_not_working
#      distance_from_centroid
# 857                     0.0
# 26
#                                                   text                                             label
# 475  i need help. I updated my balance with a check...  balance_not_updated_after_cheque_or_cash_deposit
# 549  I just transferred some money into my account ...           balance_not_updated_after_bank_transfer
# 928  I was checking the app for my account and I no...               direct_debit_payment_not_recognised
# 719  I need my account checked because it appears t...  balance_not_updated_after_cheque_or_cash_deposit
# 399  Hello. I tried doing a topup and I thought it ...                                   top_up_reverted
# 517  Hello, I went ahead and checked my account det...                                  pending_transfer
# 914  I can't find how to top up my account with a c...                          top_up_by_cash_or_cheque
# 930  Hi, I was just checking over my card transacti...                         transaction_charged_twice
# 352  I deposited cash into my account and I'm havin...  balance_not_updated_after_cheque_or_cash_deposit
# 345  What is going on with my cash deposit. I'm loo...  balance_not_updated_after_cheque_or_cash_deposit
# 82   I was trying to top up my account and it isn't...                                     top_up_failed
# 383  I have done a transfer within the country the ...                transfer_not_received_by_recipient
# 650  Hae, I already completed my 3D secure authenti...                                   top_up_reverted
# 554  Did you lose my money? I had added funds throu...                                   top_up_reverted
# 264  Hi, I sent a payment to the wrong account numb...                                   cancel_transfer
# 368  I just deposited cash to my account and can't ...  balance_not_updated_after_cheque_or_cash_deposit
# 671  Is there something wrong with the transferring...                           beneficiary_not_allowed
# 32   I thought you offer crypto top up but it doesn...                                   top_up_reverted
# 270  I have an emergency and lost my phone.  I need...                              lost_or_stolen_phone
# 428  Hi, I am interested buying crypto currency but...                           beneficiary_not_allowed
# 220  Hearing about your verification results from u...                         unable_to_verify_identity
# 698  Hi, I am disappointed to see such a bad exchan...                  card_payment_wrong_exchange_rate
# 723  It can take between 10 minutes to an hour befo...                         unable_to_verify_identity
#      distance_from_centroid
# 475                6.622118
# 549                6.970045
# 928                7.329333
# 719                7.480773
# 399                7.598560
# 517                8.393505
# 914                8.417966
# 930                8.433416
# 352                8.527809
# 345                8.785035
# 82                 8.950918
# 383                8.994927
# 650                9.008914
# 554                9.085167
# 264                9.122818
# 368                9.164326
# 671                9.172042
# 32                 9.279161
# 270                9.475034
# 428                9.876655
# 220               10.524744
# 698               10.758693
# 723               11.190189
# 27
#                                                   text                                             label
# 165            I didn't get my card back from the ATM.                                    card_swallowed
# 411             I could not access my money at the ATM                          declined_cash_withdrawal
# 419  I attempted to get cash in the ATM but it was ...                          declined_cash_withdrawal
# 976  I attempted to get cash in the ATM but I was d...                          declined_cash_withdrawal
# 941  Why did the cash deposit not show up in my acc...  balance_not_updated_after_cheque_or_cash_deposit
# 949                        I was denied cash at an ATM                          declined_cash_withdrawal
# 655          I wasn't able to withdraw money at an ATM                          declined_cash_withdrawal
# 593  Why has my card payment not yet been applied t...                              pending_card_payment
# 81                  I couldn't pay with card in a shop                             declined_card_payment
# 247  I put my check in the bank, but I haven't gott...  balance_not_updated_after_cheque_or_cash_deposit
# 346    The store card reader would not accept my card.                             declined_card_payment
# 571      Why won't the machine accept my card anymore?                                  card_not_working
# 375  How come when I tried to pay contactless at th...                           contactless_not_working
# 827  I thought I left my card at a restaurant, but ...                               lost_or_stolen_card
# 272  Can you tell me what the problem with my card ...                                  card_not_working
#      distance_from_centroid
# 165                6.681515
# 411                6.992179
# 419                7.130723
# 976                7.510018
# 941                7.512498
# 949                7.561025
# 655                7.589914
# 593                7.842269
# 81                 8.502426
# 247                8.560465
# 346                9.160170
# 571               10.105217
# 375               10.368447
# 827               10.524025
# 272               11.001605
# 28
#                                                   text                                    label
# 205  How does it work when I transfer money into my...                    transfer_into_account
# 846  When will the money from a transfer be made av...                          transfer_timing
# 135         How is my money transferred to the account                    transfer_into_account
# 410         How do I transfer cash my into my account?                    transfer_into_account
# 316  I have questions about how to transfer money t...                    transfer_into_account
# 491  How long do transfers take to show up in my ac...  balance_not_updated_after_bank_transfer
# 854                 How often can I top up my account?                            top_up_limits
# 679     What is the source of the money in my account?                   verify_source_of_funds
# 31   Can I add money to top up my account via a ban...                    transfer_into_account
# 230  How long does it take for the money to show up...                          transfer_timing
# 965  How simple is it to transfer money into my acc...                    transfer_into_account
# 60   I want to use a payment card to top up my acco...           supported_cards_and_currencies
# 271  What currencies do you accept for adding money...           supported_cards_and_currencies
# 313        Why was there a transfer fee on my account?                     transfer_fee_charged
# 65   What are the fees for using transfer to top of...           top_up_by_bank_transfer_charge
# ...
# 366               11.625019
# 572               12.143889
# 66
#                                                   text                 label
# 103  I need help right now. I realize I sent my pay...       cancel_transfer
# 807  My card information seems to have been stolen!...      compromised_card
# 183  I need urgent help. I realize I sent my paymen...       cancel_transfer
# 881  My card has been compromised. I see a bunch of...      compromised_card
# 879  My account is locked because I used the wrong ...           pin_blocked
# 480  My card was stolen and used to make several pu...      compromised_card
# 303  I misplaced my phone so I can't use the app! D...  lost_or_stolen_phone
# 961  Everything was stolen from me.  I can't use th...  lost_or_stolen_phone
# 265  I was mugged.  They took everything.  I can't ...  lost_or_stolen_phone
# 115  I punched in the wrong pin too many times and ...           pin_blocked
# 27   My card isn't working at all, I need assistanc...      card_not_working
# 344                          My card is stolen.  Help!   lost_or_stolen_card
#      distance_from_centroid
# 103                6.712472
# 807                7.289424
# 183                7.431766
# 881                7.911892
# 879                8.281337
# 480                8.407170
# 303                8.459905
# 961                8.472528
# 265                9.289474
# 115               10.003823
# 27                10.412087
# 344               12.059872
# 67
#                                                   text                        label
# 924  There was an extra fee when I paid with my car...     card_payment_fee_charged
# 6    I think a fee was applied for paying with a card.     card_payment_fee_charged
# 436  What is this extra fee that I got when I used ...     card_payment_fee_charged
# 994           I paid with card and I was charged a fee     card_payment_fee_charged
# 448        I had to pay money for paying with my card.     card_payment_fee_charged
# 687  I was charged a fee for using my card. Can I c...     card_payment_fee_charged
# 425                   I was charged for using my card?     card_payment_fee_charged
# 913  I was charged an extra dollar on my account an...    extra_charge_on_statement
# 175  I don't think I should have been charged a fee...     card_payment_fee_charged
# 833   Why do I have a strange payment on my statement?  card_payment_not_recognised
# 132  What is the Top up rate charge for using a car...        top_up_by_card_charge
#      distance_from_centroid
# 924                5.208248
# 6                  5.998175
# 436                6.099348
# 994                6.659563
# 448                6.751987
# 687                7.246776
# 425                7.345399
# 913                8.103858
# 175                8.529171
# 833                8.765611
# 132                9.797746
# 68
#                                                   text                           label
# 533          Can I link my card I previously received?                    card_linking
# 295        Is there a way to link the card i just got?                    card_linking
# 600  Is there a way to track the new card you sent me?                    card_arrival
# 782                     Can you help me track my card?                    card_arrival
# 142          What's the tracking on the card you sent?                    card_arrival
# 97          can I link a card of yours I already have?                    card_linking
# 274  What do I do if I think someone has used my card?                compromised_card
# 950           Is there a tracking number for the card?                    card_arrival
# 765  To many charges on my card how do I go about f...       transaction_charged_twice
# 327          I want to link my new card. Can you help?                    card_linking
# 196                         how do I link an old card?                    card_linking
# 544  Is there any way to get another card on the sa...              getting_spare_card
# 762  How do I link the new card that I just got fro...                    card_linking
# 232          Will my other US credit card be accepted?  supported_cards_and_currencies
#      distance_from_centroid
# 533                6.301263
# 295                6.824526
# 600                6.943328
# 782                7.215582
# 142                7.908843
# 97                 8.162254
# 274                8.203666
# 950                8.377821
# 765                8.648353
# 327                8.893101
# 196                9.407129
# 544                9.439820
# 762                9.973489
# 232               10.223247
# 69
#                                                   text                                label
# 335                 can i verify my identity i the app                   verify_my_identity
# 731           I can't verify identity through the app.            unable_to_verify_identity
# 896     Can you tell me how to get my card on the app?                         card_linking
# 988    Where in the app do I go to verify my identity?                   verify_my_identity
# 151               Can I change my pin through the app?                           change_pin
# 252  The app isn't letting me log in, but my info i...            unable_to_verify_identity
# 454                       The app failed to verify me.            unable_to_verify_identity
# 708  Hi, I am new to this. Are there any additional...             card_payment_fee_charged
# 989  I am seeing in the App a diret debit that its ...  direct_debit_payment_not_recognised
#      distance_from_centroid
# 335                6.519813
# 731                7.174773
# 896                7.634750
# 988                8.302968
# 151                9.076462
# 252                9.199897
# 454                9.605940
# 708                9.976329
# 989               10.172233
# 70
#                                                 text               label
# 371                      My top up didn't go through       top_up_failed
# 617        My top up is not showing up in my wallet!  topping_up_by_card
# 246                    My top up hasn't gone through      pending_top_up
# 223  Why is my 'top up' not showing up in my wallet?  topping_up_by_card
# 353                       I didn't cancel my top-up.     top_up_reverted
#      distance_from_centroid
# 371                7.269249
# 617                7.799933
# 246                8.509413
# 223                9.276465
# 353                9.827504
# 71
#                                                   text                label
# 716  Could I reactivate my card please, I couldn't ...         card_linking
# 438  Can I reactivate my card? I reported it lost a...         card_linking
# 818  I want to reactivate my card, I found it after...         card_linking
# 310  I would like to reactivate my card that I prev...         card_linking
# 629  Should I order a new card before I freeze my o...     compromised_card
# 179  I need to find out where the card is that I or...         card_arrival
# 558        Someone took my card without my permission.  lost_or_stolen_card
#      distance_from_centroid
# 716                7.489890
# 438                7.538898
# 818                7.763774
# 310                8.034731
# 629                9.139647
# 179                9.626688
# 558                9.667019
# 72
#                                                   text                           label
# 963                     How do I delete my account now               terminate_account
# 309                 Are you able to delete my account?               terminate_account
# 628  Please help me figure out the reason for the o...  cash_withdrawal_not_recognised
# 20                 How do I modify my account details?           edit_personal_details
# 39                I want to change my account details.           edit_personal_details
# 429                         How do I close my account?               terminate_account
# 836  I think I lost my phone.  Is there a way to pr...            lost_or_stolen_phone
# 242           I moved, can I edit my personal details?           edit_personal_details
#      distance_from_centroid
# 963                6.438104
# 309                6.640989
# 628                7.659643
# 20                 7.830460
# 39                 8.376304
# 429                8.720423
# 836                9.372915
# 242                9.550041
# 73
#                                                   text                                    label
# 279  I am seeing in the App a some cash withdrawal ...           cash_withdrawal_not_recognised
# 209               My app shows a payment I didn't make              card_payment_not_recognised
# 385    A payment that I didn't make appears in my app.              card_payment_not_recognised
# 714  Some cash withdrawal that I didn't make showed...           cash_withdrawal_not_recognised
# 167              A payment I didn't do shows in my app              card_payment_not_recognised
# 753  I checked the app and there is a payment that ...              card_payment_not_recognised
# 481  I need to figure out who has access to my card...              card_payment_not_recognised
# 290  I sent a payment but it isn't showing up in th...       transfer_not_received_by_recipient
# 210         I see cash in my app but I did not get it.           cash_withdrawal_not_recognised
# 394  I saw a fee on my app from one of my payments ...                 card_payment_fee_charged
# 906  Let me know when applying extra charges for pa...                 card_payment_fee_charged
# 604  I was just shopping online for some tickets an...                    declined_card_payment
# 268  I cannot seem to buy something online with my ...                   reverted_card_payment?
# 170  There is a withdrawal in my account I didn't m...           cash_withdrawal_not_recognised
# 112  There's a payment showing in the app today eve...      direct_debit_payment_not_recognised
# 42   There is a payment with my card which i defini...              card_payment_not_recognised
# 794  There are transactions that I did not make on ...                         compromised_card
# 745  Please help me as my online payment is getting...                        declined_transfer
# 885  I topped up my account but the app failed to p...                            top_up_failed
# 37   I've transferred money into my account but the...  balance_not_updated_after_bank_transfer
# 697     I did a payment but it was reverted by the app                   reverted_card_payment?
# 53   Someone withdrew money from my account, and it...           cash_withdrawal_not_recognised
# 592   THere is some cash that is showing up on my app.           cash_withdrawal_not_recognised
# 380  I think there's a purchase at a store that I d...              card_payment_not_recognised
# 28   My Netflix subscription says that there is an ...                         card_not_working
# 89   My wallet is empty even though I topped it up ...                       topping_up_by_card
#      distance_from_centroid
# 279                6.222218
# 209                6.329337
# 385                6.455865
# 714                6.541345
# 167                6.662487
# 753                6.666099
# 481                6.885417
# 290                7.255036
# 210                7.409026
# 394                7.466640
# 906                7.502415
# 604                7.522103
# 268                7.527333
# 170                8.058086
# 112                8.113979
# 42                 8.148904
# 794                8.615535
# 745                8.928232
# 885                9.137786
# 37                 9.814021
# 697                9.912503
# 53                 9.996653
# 592               10.291530
# 380               10.987464
# 28                11.370078
# 89                12.104725
# 74
#                                                   text                     label
# 110  What is the process for activating my card and...          activate_my_card
# 974           I have my card now how do I activate it?          activate_my_card
# 71                   How much can I top up on my card?             top_up_limits
# 125               How can I make my card ready to use?          activate_my_card
# 434     Can someone assist me with activating my card?          activate_my_card
# 153  What needs to be done to activate and use a card?          activate_my_card
# 944    What is the procedure for activating this card?          activate_my_card
# 442                 Where do I go to activate my card?          activate_my_card
# 849  Where can I find the verification code for the...             verify_top_up
# 326         What is the proper way to activate a card?          activate_my_card
# 177       Explain to me how to verify the top-up card.             verify_top_up
# 817  How do I find the code needed in order to veri...             verify_top_up
# 10               what steps do i do to get a real card       order_physical_card
# 936  Is my card actually working? It's the first ti...  declined_cash_withdrawal
# 365  Help me access the card I already got so I can...              card_linking
# 46                      My card needs to be topped up.        topping_up_by_card
# 970                       Please verify my top-up card             verify_top_up
# 509                I need my card to be delivered fast    card_delivery_estimate
# 388                          Send me my card now! ASAP    card_delivery_estimate
#      distance_from_centroid
# 110                6.751153
# 974                7.494854
# 71                 7.495325
# 125                7.624846
# 434                7.638318
# 153                8.143217
# 944                8.161939
# 442                8.383929
# 849                8.591223
# 326                8.704727
# 177                8.777274
# 817                8.902492
# 10                 9.563676
# 936                9.914481
# 365               10.352787
# 46                10.355520
# 970               10.498127
# 509               11.914787
# 388               12.048869
# 75
#                                                   text                     label
# 620                          Where is my virtual card?      getting_virtual_card
# 173  I heard you have virtual cards. How do I get one?      getting_virtual_card
# 675    I would like a virtual card...how do I get one?      getting_virtual_card
# 920                why hasn't my virtual card arrived?      getting_virtual_card
# 134               why hasn't my virtual card come yet?      getting_virtual_card
# 116                       How to receive virtual card?      getting_virtual_card
# 946              Is there a way to get a virtual card?      getting_virtual_card
# 739  Which part of the app do I order virtual cards...      getting_virtual_card
# 713       How do I get this damn virtual card to work?  virtual_card_not_working
# 983  Why can't I make multiple payments with my vir...  virtual_card_not_working
# 580           I haven't received my virtual card yet!!      getting_virtual_card
# 214       I can't make purchases with my virtual card.  virtual_card_not_working
#      distance_from_centroid
# 620                6.239634
# 173                6.557044
# 675                6.739149
# 920                6.807153
# 134                6.967730
# 116                7.217283
# 946                7.294124
# 739                8.054839
# 713                8.109740
# 983                8.240749
# 580                8.419763
# 214                8.997137
# 76
#                                                   text                   label
# 750    Why has my money been returned back to my card.  reverted_card_payment?
# 718     Tell me why my card payment would be reverted.  reverted_card_payment?
# 521  Hi, I have done a topup, but my money was reve...         top_up_reverted
# 706                       My card payment was reverted  reverted_card_payment?
# 953          I think my card payment has been refunded  reverted_card_payment?
# 293     I think the payment from my card was revereted  reverted_card_payment?
# 926  I was checking my statement and my top-up has ...         top_up_reverted
#      distance_from_centroid
# 750                7.235498
# 718                7.464436
# 521                7.720730
# 706                7.790512
# 953                8.126625
# 293                8.936141
# 926                9.272851

# %%
print(res.get_group(49)[['text','label']])
# Out:
#                                                   text                           label
# 281  Why did you charge me a fee when I made a tran...            transfer_fee_charged
# 181  I was charged a fee for the transfer, but can ...            transfer_fee_charged
# 102  Where did my extra fee for the transfer come f...            transfer_fee_charged
# 98         How much would I be charged for a transfer?  top_up_by_bank_transfer_charge
# 13   why was a extra fee added to my account for tr...            transfer_fee_charged
# 464  Why was I charged a random fee for a transfer ...            transfer_fee_charged
# 923  I noticed a charge for a transfer.  Why is thi...            transfer_fee_charged
# 927  There is a fee from a transfer that is not sup...            transfer_fee_charged
# 21         Will I be fined for topping up by transfer?  top_up_by_bank_transfer_charge
# 877  I don't understand why I was charged an additi...        card_payment_fee_charged
# 453             What is the handling fee for transfer?  top_up_by_bank_transfer_charge
# 138  Will you guys charge me for topping up by tran...  top_up_by_bank_transfer_charge
# 382        When I made a transfer I was charged extra.            transfer_fee_charged
# 882                      Why am I being charged again?       transaction_charged_twice

# %%
res.count()
# Out:
#          text  label  emb  centroid  distance_from_centroid
# cluster
# 0          21     21   21        21                      21
# 1           7      7    7         7                       7
# 2          10     10   10        10                      10
# 3           6      6    6         6                       6
# 4           3      3    3         3                       3
# ...       ...    ...  ...       ...                     ...
# 72          8      8    8         8                       8
# 73         26     26   26        26                      26
# 74         19     19   19        19                      19
# 75         12     12   12        12                      12
# 76          7      7    7         7                       7
#
# [77 rows x 5 columns]
